# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
# Defining video path / output directory  
video_path = "/Users/lancelotbosseler/code/labosseler/final-project/final-attention/notebooks/trial-images/real-life-test/VID_20230309_103436.mp4"
output_path = os.path.join(os.path.expanduser('~'), "Desktop", "origin")

# %%
video = cv2.VideoCapture(video_path)

# %%
# FPS
fps = video.get(cv2.CAP_PROP_FPS)

# %%
# FRAME COUNT
frame_count = video.get(cv2.CAP_PROP_FRAME_COUNT)

# %%
# Setting video to end
video.set(cv2.CAP_PROP_POS_FRAMES, frame_count -1)
video.get(cv2.CAP_PROP_POS_FRAMES)
# Out:
# 720.0

# %%
# DURATION
duration = frame_count/fps * 1000

# %%
# Setting video to end
max_msec = duration - 1/fps * 1000
video.set(cv2.CAP_PROP_POS_MSEC, max_msec)
# Out:
# True

# %%
# Showing frame
ret, frame = video.read()
plt.imshow(frame)

# %%
msec = np.linspace(0, max_msec, 48)

# %%
for idx, time in enumerate(msec): 
    video.set(cv2.CAP_PROP_POS_MSEC, time)
    ret, frame = video.read()
    photo_capture = frame[100:900, 10:1800]
    cv2.imwrite(os.path.join(output_path, f'frame_{idx}.png'), photo_capture)
